# %% [markdown]
# # Les calcules Mathématiques en Numpy

# %%
import numpy as np

# %%
A = np.full((2, 2), 5)

# %%
A
# Out:
# array([[5, 5],
#        [5, 5]])

# %%
B = np.random.randint(0,9, [2, 3])

# %%
B
# Out:
# array([[5, 0, 8],
#        [2, 1, 7]])

# %%
B.sum(axis=1)
# Out:
# array([13, 10])

# %%
B.sum(axis=0)
# Out:
# array([ 7,  1, 15])

# %%
B.min(axis=1)
# Out:
# array([0, 1])

# %%
B.min(axis=0)
# Out:
# array([2, 0, 7])

# %%
B.max(axis=1)
# Out:
# array([8, 7])

# %%
B.max(axis=0)
# Out:
# array([5, 1, 8])

# %%
np.max(B, axis=1)
# Out:
# array([8, 7])

# %%
import math as mt
angle = np.random.randint(0, mt.pi, [5, 5])

# %%
angle
# Out:
# array([[0, 1, 0, 2, 2],
#        [0, 0, 0, 2, 1],
#        [1, 2, 2, 0, 1],
#        [1, 0, 2, 1, 0],
#        [0, 2, 1, 0, 2]])

# %%
np.sin(angle)
# Out:
# array([[0.        , 0.84147098, 0.        , 0.90929743, 0.90929743],
#        [0.        , 0.        , 0.        , 0.90929743, 0.84147098],
#        [0.84147098, 0.90929743, 0.90929743, 0.        , 0.84147098],
#        [0.84147098, 0.        , 0.90929743, 0.84147098, 0.        ],
#        [0.        , 0.90929743, 0.84147098, 0.        , 0.90929743]])

# %%
np.exp(angle)
# Out:
# array([[1.        , 2.71828183, 1.        , 7.3890561 , 7.3890561 ],
#        [1.        , 1.        , 1.        , 7.3890561 , 2.71828183],
#        [2.71828183, 7.3890561 , 7.3890561 , 1.        , 2.71828183],
#        [2.71828183, 1.        , 7.3890561 , 2.71828183, 1.        ],
#        [1.        , 7.3890561 , 2.71828183, 1.        , 7.3890561 ]])

# %% [markdown]
# # Les Calcules Statistiques

# %%
np.corrcoef(angle)
# Out:
# array([[ 1.        ,  0.83852549, -0.5976143 , -0.5976143 ,  0.25      ],
#        [ 0.83852549,  1.        , -0.86859904, -0.13363062, -0.2795085 ],
#        [-0.5976143 , -0.86859904,  1.        ,  0.07142857,  0.5976143 ],
#        [-0.5976143 , -0.13363062,  0.07142857,  1.        , -0.5976143 ],
#        [ 0.25      , -0.2795085 ,  0.5976143 , -0.5976143 ,  1.        ]])

# %%
np.unique(angle, return_counts=True)
# Out:
# (array([0, 1, 2]), array([10,  7,  8], dtype=int64))

# %%
val = np.unique(angle, return_counts=True)[0]
occurs = np.unique(angle, return_counts=True)[1]
print(val)
print(occurs)
print(val[np.argsort(occurs)])
print(occurs[np.argsort(occurs)])
# Out:
# [0 1 2]
# [10  7  8]
# [1 2 0]
# [ 7  8 10]

# %%
angle
# Out:
# array([[0, 1, 0, 2, 2],
#        [0, 0, 0, 2, 1],
#        [1, 2, 2, 0, 1],
#        [1, 0, 2, 1, 0],
#        [0, 2, 1, 0, 2]])

# %%
for valeur, occurence in zip(val[np.argsort(occurs)][::-1], occurs[np.argsort(occurs)][::-1]):
    print('la valeur: {} apparaît {} fois'.format(valeur, occurence))
# Out:
# la valeur: 0 apparaît 10 fois
# la valeur: 2 apparaît 8 fois
# la valeur: 1 apparaît 7 fois

# %%
AA = np.array([[1, 5, np.nan, 8, 9], [7, np.nan, 6, 3, 4], [9, 8, 2, 1, 3], [1, 23, 3, 4, 8], [ np.nan, 12, np.nan, 4, 88]])

# %%
AA
# Out:
# array([[ 1.,  5., nan,  8.,  9.],
#        [ 7., nan,  6.,  3.,  4.],
#        [ 9.,  8.,  2.,  1.,  3.],
#        [ 1., 23.,  3.,  4.,  8.],
#        [nan, 12., nan,  4., 88.]])

# %%
np.isnan(AA).sum()
# Out:
# 4

# %%
np.std(AA)
# Out:
# nan

# %%
np.var(AA)
# Out:
# nan

# %%
np.mean(AA)
# Out:
# nan

# %%
np.nanstd(AA)
# Out:
# 18.104133152079076

# %%
np.nanvar(AA)
# Out:
# 327.75963718820867

# %%
np.nanstd(AA)
# Out:
# 18.104133152079076

# %%
AA
# Out:
# array([[ 1.,  5., nan,  8.,  9.],
#        [ 7., nan,  6.,  3.,  4.],
#        [ 9.,  8.,  2.,  1.,  3.],
#        [ 1., 23.,  3.,  4.,  8.],
#        [nan, 12., nan,  4., 88.]])

# %%
print('Nous avons {} % de données corrompue dans notre dataset'.format((np.isnan(AA).sum()/AA.size)*100))
# Out:
# Nous avons 16.0 % de données corrompue dans notre dataset

# %%
np.isnan(AA)
# Out:
# array([[False, False,  True, False, False],
#        [False,  True, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [ True, False,  True, False, False]])

# %%
AA[np.isnan(AA)] = np.nanmean(AA)

# %%
AA
# Out:
# array([[ 1.        ,  5.        ,  9.95238095,  8.        ,  9.        ],
#        [ 7.        ,  9.95238095,  6.        ,  3.        ,  4.        ],
#        [ 9.        ,  8.        ,  2.        ,  1.        ,  3.        ],
#        [ 1.        , 23.        ,  3.        ,  4.        ,  8.        ],
#        [ 9.95238095, 12.        ,  9.95238095,  4.        , 88.        ]])

# %%
print('Nous avons {} % de données corrompue dans notre dataset'.format((np.isnan(AA).sum()/AA.size)*100))
# Out:
# Nous avons 0.0 % de données corrompue dans notre dataset

# %% [markdown]
# # Algèbre Linéaire

# %%
A = np.ones((2, 3))
B = np.ones((3, 2))
A
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
B
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
A.T.shape
# Out:
# (3, 2)

# %%
A.dot(B)
# Out:
# array([[3., 3.],
#        [3., 3.]])

# %%
B.dot(A)
# Out:
# array([[2., 2., 2.],
#        [2., 2., 2.],
#        [2., 2., 2.]])

# %%
A = np.random.randint(0, 10, [3, 3])

# %%
A
# Out:
# array([[5, 9, 2],
#        [9, 2, 0],
#        [2, 1, 4]])

# %%
np.linalg.det(A)
# Out:
# -274.00000000000006

# %%
np.linalg.pinv(A)
# Out:
# array([[-0.02919708,  0.12408759,  0.01459854],
#        [ 0.13138686, -0.05839416, -0.06569343],
#        [-0.01824818, -0.04744526,  0.25912409]])

# %%
np.linalg.eig(A)
# Out:
# (array([-5.69611404, 12.99424755,  3.70186649]),
#  array([[ 0.64890152, -0.75200115, -0.03994902],
#         [-0.75883929, -0.61559559, -0.21126288],
#         [-0.05558554, -0.2356615 ,  0.97661255]]))

# %% [markdown]
# # Exercice

# %% [markdown]
# Zoom d'un l'image face de misc

# %%
from scipy import misc
import matplotlib.pyplot as plt

# %%
face = misc.face()
plt.imshow(face)
plt.show()

# %%
face = misc.face(gray=True)
face = face[::4, ::2]
plt.imshow(face, cmap=plt.cm.gray)
plt.show()

# %%
heigth = face.shape[0]
width = face.shape[1]

# %%
heigth
# Out:
# 768

# %%
width
# Out:
# 1024

# %%
zoom = face[heigth//4:-heigth//4, width//4:-width//4]

# %%
plt.imshow(zoom, cmap=plt.cm.gray)
plt.show()

# %%
zoom[zoom>=150] = 255
plt.imshow(zoom)
plt.show()
