# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target
names = list(iris.target_names)

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables ')
print(f'il y a {np.unique(y).size} classe')
# Out:
# x contient 150 exemples et 4 variables
# il y a 3 classe

# %% [markdown]
# # 5 Graphique Scatter pour les problèmes de classification

# %%
plt.scatter(x[:, 2], x[:,3], c=y, s=x[:, 1]*60)

# %%
names
# Out:
# ['setosa', 'versicolor', 'virginica']

# %% [markdown]
# # 4 Graphique 3D mpl_toolkits

# %%
# %matplotlib
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.scatter(x[:, 0], x[:, 1], x[:, 2], c=y)
plt.show()

# %%
f = lambda x, y: np.sin(x) + np.cos(x+y)

# %%
x = np.linspace(0,5, 10)
y = np.linspace(0, 5, 100)

X, Y = np.meshgrid(x, y)

# %%
Z = f(X, Y)

# %%
ax = plt.axes(projection="3d")
ax.plot_surface(X, Y, Z, cmap="plasma")

# %% [markdown]
# # 3 Histogramme

# %%
x = iris.data
y = iris.target

# %%
plt.hist(x[:, 0], bins=50)
plt.hist(x[:, 1], bins=50)
# Out:
# (array([ 1.,  0.,  0.,  0.,  3.,  0.,  4.,  0.,  3.,  0.,  8.,  0.,  5.,
#          0.,  9.,  0., 14.,  0., 10.,  0., 26.,  0., 11.,  0.,  0., 13.,
#          0.,  6.,  0., 12.,  0.,  6.,  0.,  4.,  0.,  3.,  0.,  6.,  0.,
#          2.,  0.,  1.,  0.,  1.,  0.,  1.,  0.,  0.,  0.,  1.]),
#  array([2.   , 2.048, 2.096, 2.144, 2.192, 2.24 , 2.288, 2.336, 2.384,
#         2.432, 2.48 , 2.528, 2.576, 2.624, 2.672, 2.72 , 2.768, 2.816,
#         2.864, 2.912, 2.96 , 3.008, 3.056, 3.104, 3.152, 3.2  , 3.248,
#         3.296, 3.344, 3.392, 3.44 , 3.488, 3.536, 3.584, 3.632, 3.68 ,
#         3.728, 3.776, 3.824, 3.872, 3.92 , 3.968, 4.016, 4.064, 4.112,
#         4.16 , 4.208, 4.256, 4.304, 4.352, 4.4  ]),
#  <a list of 50 Patch objects>)

# %%
plt.hist2d(x[:, 0], x[:, 1])
plt.xlabel('longueur Sépal')
plt.ylabel('largeur Sépal')
plt.colorbar()

# %%
from scipy import misc
face = misc.face(gray=True)
plt.imshow(face, cmap='gray')
plt.hist(face.ravel(), bins=255)
plt.show()

# %% [markdown]
# # 2 Graphique Contourplot

# %%
plt.contour(X, Y, Z, 20, colors='gold')

# %%
plt.contourf(X, Y, Z, cmap='RdGy')

# %% [markdown]
# # 1 Graphique Imshow

# %%
face = misc.face()
plt.imshow(face)

# %%
plt.imshow(np.corrcoef(x.T), cmap="Blues")
plt.colorbar()
plt.show()

# %% [markdown]
# # Corrigé Exercice 14/30

# %%
dataset = {f'experiece {i}': np.random.randn(100, 3) for i in range(7)}

# %%
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12, 16))
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n, 1, i)
        plt.plot(data[k], label="la sinusoïdale")
        plt.title(k)
        plt.xlabel('Axe X')
        plt.ylabel('Axe Y')
        plt.legend()
    plt.show()

# %%
graphique(dataset)
